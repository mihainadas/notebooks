# %% [markdown]
# # Hugging Face Deployed Models
#
# This short notebook shows how to list all the models that are currently deployed on the Hugging Face Inference API.

# %%
from huggingface_hub import InferenceClient
from decouple import config

HF_TOKEN = config('HF_TOKEN')
client = InferenceClient(token=HF_TOKEN)
client.list_deployed_models()
# Out:
# {'feature-extraction': ['aari1995/German_Semantic_STS_V2',
#   'BAAI/bge-base-en-v1.5',
#   'flax-sentence-embeddings/all_datasets_v3_roberta-large',
#   'intfloat/multilingual-e5-large-instruct',
#   'mixedbread-ai/mxbai-embed-large-v1',
#   'NeuML/pubmedbert-base-embeddings',
#   'openai/whisper-large-v3-turbo',
#   'sentence-transformers/all-MiniLM-L12-v2',
#   'sentence-transformers/all-MiniLM-L6-v2',
#   'sentence-transformers/all-mpnet-base-v2',
#   'sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2',
#   'stabilityai/stable-diffusion-xl-base-1.0',
#   'WhereIsAI/UAE-Large-V1'],
#  'image-to-image': ['stabilityai/stable-diffusion-xl-refiner-1.0'],
#  'text-to-image': ['black-forest-labs/FLUX.1-dev',
#   'black-forest-labs/FLUX.1-schnell',
#   'circulus/sd-photoreal-semi-v2',
#   'CompVis/stable-diffusion-v1-4',
#   'digiplay/AbsoluteReality_v1.8.1',
#   'digiplay/AnalogMadness-realistic-model-v4',
#   'digiplay/AnalogMadness-realistic-model-v5',
# ...
